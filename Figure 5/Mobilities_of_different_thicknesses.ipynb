# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
import matplotlib.colors as colors
import seaborn as sns
import pandas as pd
import scipy.misc
from mpl_toolkits.mplot3d import Axes3D
from skimage.io import imread
from matplotlib import cm as cm

# %%
mob_0g_7L = [11.39479,13.0829,10.7499,19.8682,5.94821,0.21532,0.00187]
mob_60g_7L = [18.54694,15.48975,14.77842,18.32788,17.2238,13.45236,9.80214]
time_7L = [0, 2, 4, 6, 8, 10, 12]

mob_0g_1L = [1.00799,0.45586,0.2116,0.02886,0.02689,4.79817E-4]
mob_60g_1L = [30.57085,16.54733,13.71582,0.93755,0.75633,0.00306]
time_1L = [0, 2, 4, 6, 8, 10]

mob_0g_2L = [12.80246,3.2031,1.80324,1.47323,1.15668,0.02338,1.62036E-4]
mob_60g_2L = [29.0847,31.84501,22.91914,16.833,14.99516,1.13623,0.31555]
time_2L = [0, 2, 4, 6, 8, 10, 12]

mob_0g_3L = [4.97801,5.70309,4.76048,0.7574,1.64782,0.01344]
mob_60g_3L = [36.78174,33.50195,30.95157,19.68317,16.19197,0.25195]
time_3L = [0, 2, 4, 6, 8, 10]

mob_0g_5L = [26.63977,22.79812,19.12979,3.50931,4.72399,0.06974]
mob_60g_5L = [41.86817,40.79286,36.63545,32.19401,28.14795,7.08256]
time_5L = [0, 2, 4, 6, 8, 10]

mob_0g_6L = [25.2839,13.66069,11.94421,4.23628,6.41467,0.16629]
mob_60g_6L = [26.89022,26.81526,26.28769,27.59957,24.51134,21.81694]
time_6L = [0, 2, 4, 6, 8, 10]

mob_0g_9L = [31.36806,24.79068,21.96192,9.94474,16.12137,0.18476]
mob_60g_9L = [9.81017,19.5507,9.72109,11.1477,9.8556,12.8135]
time_9L = [0, 2, 4, 6, 8, 10]

mob_0g_4L = [36.89602,37.6,26.40917,44.74095,8.62377,0.15157,3.88829E-4]
mob_60g_4L = [109.02539,100.97746,94.45485,79.31059,62.55372,6.49133,1.33227]
time_4L = [0,2,4,6,8,10,12]

# %%
fig = plt.figure(figsize=(4,4))
fig.canvas.draw()

sns.set_style('ticks')

ax3 = fig.add_subplot(111, axisbg="white")
ax3.plot(time_7L,mob_0g_7L, '-o', ms=12, color = '#036564', lw=2, alpha=0.7,
         mfc='#036564', dash_capstyle = 'butt', mew = '1', label = 'Gate bias = 0 V' ) 
ax3.plot(time_7L,mob_60g_7L, '-^', ms=12, color = 'r',  lw=2, alpha=0.7, mfc='red', 
         dash_capstyle = 'butt', mew = '1', 
              label = 'Gate bias = 60 V' ) 

ax3.grid('off')
ax3.set_title('7 Layer', fontsize = 17)
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('right')
ax3.set_xlabel('Plasma time (s)', fontsize = 12)
ax3.set_ylabel('$\mu_{FE}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
ax3.set_ylim([-4,30])
ax3.set_xlim([-1,13])
plt.tight_layout()
ax3.legend(loc = 'upper right', ncol = 1, fontsize=12)
plt.savefig("mobilities_7L",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
fig.canvas.draw()

sns.set_style('ticks')

ax3 = fig.add_subplot(111, axisbg="white")
ax3.plot(time_1L,mob_0g_1L, '-o', ms=12, color = '#036564', lw=2, alpha=0.7,
         mfc='#036564', dash_capstyle = 'butt', mew = '1', label = 'Gate bias = 0 V' ) 
ax3.plot(time_1L,mob_60g_1L, '-^', ms=12, color = 'r',  lw=2, alpha=0.7, mfc='red', 
         dash_capstyle = 'butt', mew = '1', 
              label = 'Gate bias = 60 V' ) 

ax3.grid('off')
ax3.set_title('1 Layer', fontsize = 17)
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('right')
ax3.set_xlabel('Plasma time (s)', fontsize = 12)
ax3.set_ylabel('$\mu_{FE}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
ax3.set_ylim([-4,35])
ax3.set_xlim([-1,11])
plt.tight_layout()
ax3.legend(loc = 'upper right', ncol = 1, fontsize=12)
plt.savefig("mobilities_1L",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
fig.canvas.draw()

sns.set_style('ticks')

ax3 = fig.add_subplot(111, axisbg="white")
ax3.plot(time_2L,mob_0g_2L, '-o', ms=10, color = '#036564', lw=2, alpha=0.7,
         mfc='#036564', dash_capstyle = 'butt', mew = '1', label = 'Gate bias = 0 V' ) 
ax3.plot(time_2L,mob_60g_2L, '-^', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', 
         dash_capstyle = 'butt', mew = '1', 
              label = 'Gate bias = 60 V' ) 

ax3.grid('on')
ax3.set_title('Mobility evolution of 2L sample')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.set_xlabel('Plasma time (s)', fontsize = 10)
ax3.set_ylabel('$\mu_{FE}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 10)
ax3.set_ylim([-5,35])
ax3.set_xlim([-1,13])
plt.tight_layout()
ax3.legend(loc = 'upper right', ncol = 1, fontsize=10)
plt.savefig("mobilities_2L",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
fig.canvas.draw()

sns.set_style('ticks')

ax3 = fig.add_subplot(111, axisbg="white")
ax3.plot(time_3L,mob_0g_3L, '-o', ms=10, color = '#036564', lw=2, alpha=0.7,
         mfc='#036564', dash_capstyle = 'butt', mew = '1', label = 'Gate bias = 0 V' ) 
ax3.plot(time_3L,mob_60g_3L, '-^', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', 
         dash_capstyle = 'butt', mew = '1', 
              label = 'Gate bias = 60 V' ) 

ax3.grid('on')
ax3.set_title('Mobility evolution of 3L sample')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.set_xlabel('Plasma time (s)', fontsize = 10)
ax3.set_ylabel('$\mu_{FE}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 10)
ax3.set_ylim([-5,40])
ax3.set_xlim([-1,11])
plt.tight_layout()
ax3.legend(loc = 'upper right', ncol = 1, fontsize=10)
plt.savefig("mobilities_3L",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
fig.canvas.draw()

sns.set_style('ticks')

ax3 = fig.add_subplot(111, axisbg="white")
ax3.plot(time_5L,mob_0g_5L, '-o', ms=10, color = '#036564', lw=2, alpha=0.7,
         mfc='#036564', dash_capstyle = 'butt', mew = '1', label = 'Gate bias = 0 V' ) 
ax3.plot(time_5L,mob_60g_5L, '-^', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', 
         dash_capstyle = 'butt', mew = '1', 
              label = 'Gate bias = 60 V' ) 

ax3.grid('on')
ax3.set_title('Mobility evolution of 5L sample')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.set_xlabel('Plasma time (s)', fontsize = 10)
ax3.set_ylabel('$\mu_{FE}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 10)
ax3.set_ylim([-5,45])
ax3.set_xlim([-1,11])
plt.tight_layout()
ax3.legend(loc = 'lower left', ncol = 1, fontsize=10)
plt.savefig("mobilities_5L",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
fig.canvas.draw()

sns.set_style('ticks')

ax3 = fig.add_subplot(111, axisbg="white")
ax3.plot(time_6L,mob_0g_6L, '-o', ms=10, color = '#036564', lw=2, alpha=0.7,
         mfc='#036564', dash_capstyle = 'butt', mew = '1', label = 'Gate bias = 0 V' ) 
ax3.plot(time_6L,mob_60g_6L, '-^', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', 
         dash_capstyle = 'butt', mew = '1', 
              label = 'Gate bias = 60 V' ) 

ax3.grid('on')
ax3.set_title('Mobility evolution of 6L sample')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.set_xlabel('Plasma time (s)', fontsize = 10)
ax3.set_ylabel('$\mu_{FE}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 10)
ax3.set_ylim([-5,30])
ax3.set_xlim([-1,11])
plt.tight_layout()
ax3.legend(loc = 'lower left', ncol = 1, fontsize=10)
plt.savefig("mobilities_6L",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
fig.canvas.draw()

sns.set_style('ticks')

ax3 = fig.add_subplot(111, axisbg="white")
ax3.plot(time_9L,mob_0g_9L, '-o', ms=10, color = '#036564', lw=2, alpha=0.7,
         mfc='#036564', dash_capstyle = 'butt', mew = '1', label = 'Gate bias = 0 V' ) 
ax3.plot(time_9L,mob_60g_9L, '-^', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', 
         dash_capstyle = 'butt', mew = '1', 
              label = 'Gate bias = 60 V' ) 

ax3.grid('on')
ax3.set_title('Mobility evolution of 9L sample')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.set_xlabel('Plasma time (s)', fontsize = 10)
ax3.set_ylabel('$\mu_{FE}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 10)
ax3.set_ylim([-5,40])
ax3.set_xlim([-1,11])
plt.tight_layout()
ax3.legend(loc = 'lower left', ncol = 1, fontsize=10)
plt.savefig("mobilities_9L",bbox_inches='tight', dpi = 600)
plt.show()

# %%
fig = plt.figure(figsize=(4,4))
fig.canvas.draw()

sns.set_style('ticks')

ax3 = fig.add_subplot(111, axisbg="white")
ax3.plot(time_4L,mob_0g_4L, '-o', ms=10, color = '#036564', lw=2, alpha=0.7,
         mfc='#036564', dash_capstyle = 'butt', mew = '1', label = 'Gate bias = 0 V' ) 
ax3.plot(time_4L,mob_60g_4L, '-^', ms=10, color = 'r',  lw=2, alpha=0.7, mfc='red', 
         dash_capstyle = 'butt', mew = '1', 
              label = 'Gate bias = 60 V' ) 

ax3.grid('on')
ax3.set_title('Mobility evolution of 4L sample')
ax3.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.set_xlabel('Plasma time (s)', fontsize = 10)
ax3.set_ylabel('$\mu_{FE}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 10)
ax3.set_ylim([-5,120])
ax3.set_xlim([-1,13])
plt.tight_layout()
ax3.legend(loc = 'lower left', ncol = 1, fontsize=10)
plt.savefig("mobilities_4L",bbox_inches='tight', dpi = 300)
plt.show()
