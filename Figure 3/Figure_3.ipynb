# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
import scipy.misc
from mpl_toolkits.mplot3d import Axes3D
from skimage.io import imread
from matplotlib import cm as cm

# %%
x = []
y = []
z = []



with open('deltaomega.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))
        z.append(float(row[2]))

# %%
x1 = []
y1 = []
z1 = []
a1 = []
b1 = []
c1 = []
d1 = []
e1 = []


with open('Raman.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x1.append(float(row[0]))
        y1.append(float(row[1]))
        z1.append(float(row[2]))
        a1.append(float(row[3]))
        b1.append(float(row[4]))
        c1.append(float(row[5]))
        d1.append(float(row[6]))
        e1.append(float(row[7]))

# %%
x2 = []
y2 = []
z2 = []
a2 = []
b2 = []


with open('PL.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x2.append(float(row[0]))
        y2.append(float(row[1]))
        z2.append(float(row[2]))
        a2.append(float(row[3]))
        b2.append(float(row[4]))

# %%
x3 = []
y3 = []
z3 = []



with open('EDXratio.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x3.append(float(row[0]))
        y3.append(float(row[1]))
        z3.append(float(row[2]))

# %%
x_s0s = []
y_s0s = []
z_s0s = []
a_s0s = []
b_s0s = []
c_s0s = []
with open('s2p0s.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_s0s.append(float(row[0]))
        y_s0s.append(float(row[1]))
        z_s0s.append(float(row[2]))
        a_s0s.append(float(row[3]))
        b_s0s.append(float(row[4]))
        c_s0s.append(float(row[5]))

# %%
x_s6s = []
y_s6s = []
z_s6s = []
a_s6s = []
b_s6s = []
c_s6s = []
with open('s2p6s.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_s6s.append(float(row[0]))
        y_s6s.append(float(row[1]))
        z_s6s.append(float(row[2]))
        a_s6s.append(float(row[3]))
        b_s6s.append(float(row[4]))
        c_s6s.append(float(row[5]))

# %%
x_s10s = []
y_s10s = []
z_s10s = []
a_s10s = []
b_s10s = []
c_s10s = []
with open('s2p10s.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_s10s.append(float(row[0]))
        y_s10s.append(float(row[1]))
        z_s10s.append(float(row[2]))
        a_s10s.append(float(row[3]))
        b_s10s.append(float(row[4]))
        c_s10s.append(float(row[5]))

# %%
x_mo0s = []
y_mo0s = []
z_mo0s = []
a_mo0s = []
b_mo0s = []
c_mo0s = []
with open('mo3d0s.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_mo0s.append(float(row[0]))
        y_mo0s.append(float(row[1]))
        z_mo0s.append(float(row[2]))
        a_mo0s.append(float(row[3]))
        b_mo0s.append(float(row[4]))
        c_mo0s.append(float(row[5]))

# %%
x_mo6s = []
y_mo6s = []
z_mo6s = []
a_mo6s = []
b_mo6s = []
c_mo6s = []
d_mo6s = []
e_mo6s = []
f_mo6s = []
with open('mo3d6s.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_mo6s.append(float(row[0]))
        y_mo6s.append(float(row[1]))
        z_mo6s.append(float(row[2]))
        a_mo6s.append(float(row[3]))
        b_mo6s.append(float(row[4]))
        c_mo6s.append(float(row[5]))
        d_mo6s.append(float(row[6]))
        e_mo6s.append(float(row[7]))

# %%
x_mo10s = []
y_mo10s = []
z_mo10s = []
a_mo10s = []
b_mo10s = []
c_mo10s = []
d_mo10s = []
e_mo10s = []
f_mo10s = []
g_mo10s = []
with open('mo3d10s.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x_mo10s.append(float(row[0]))
        y_mo10s.append(float(row[1]))
        z_mo10s.append(float(row[2]))
        a_mo10s.append(float(row[3]))
        b_mo10s.append(float(row[4]))
        c_mo10s.append(float(row[5]))
        d_mo10s.append(float(row[6]))
        e_mo10s.append(float(row[7]))

# %%
fig = plt.figure(figsize=(2,2))

axes = fig.add_subplot(111)

axes.set_xlabel('Exposure time (s)', fontsize = 10)
axes.set_ylabel('$\Delta \omega$ (cm$^{-1}$)', fontsize = 12)
plt.yticks(fontsize = 8)
plt.xticks(fontsize = 8)
axes.grid('off')
axes.set_xlim([-1,9])
axes.yaxis.set_label_position("right")
axes.yaxis.tick_right()
#major_ticks_1 = np.arange(0, 8,2 )   
#axes.set_xticks(major_ticks_1)  
#major_ticks_2 = np.arange(10, 35,10 )   
#axes.set_yticks(major_ticks_2)  
plt.tight_layout()
axes.errorbar(x,y, yerr = z, ls = 'dashed', c = "green", marker = 'h', alpha=0.7, mfc='green', mew = '0.5', markersize = 8, label = '0 s' )
plt.savefig("fig3a_inset.jpg", bbox_inches='tight', dpi = 300)

plt.show()

# %%
fig = plt.figure(figsize=(3,3))

axes = fig.add_subplot(111)

axes.set_xlabel('Wavenumber (cm$^{-1}$)', fontsize = 12)
axes.set_ylabel('Intensity (a.u.)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)

axes.set_yscale("log")
axes.grid('off')


axes.plot(x1,z1, color='black', linestyle='-', linewidth=3, label = '0 s' )
axes.plot(x1,a1, color='blue', linestyle='-', linewidth=3, label = '2 s')
axes.plot(x1,b1, color='orange', linestyle='-', linewidth=3, label = '4 s')
axes.plot(x1,c1, color='red', linestyle='-', linewidth=3, label = '6 s')
axes.plot(x1,d1, color='olive', linestyle='-', linewidth=3, label = '8 s')
axes.plot(x1,e1, color='darkviolet', linestyle='-', linewidth=3, label = '10 s')
major_ticks_1 = np.arange(340, 480, 60)   
axes.set_xticks(major_ticks_1)  

axes.set_xlim([340,475])
axes.set_ylim([1000,40000])

plt.setp(axes.get_yticklabels(), visible=True, fontsize = 12)
plt.setp(axes.get_xticklabels(), visible=True, fontsize = 12)
axes.legend(bbox_to_anchor=(0.25, 1.15),labelspacing=0.01, fontsize = 10)



plt.savefig("fig3a.png", bbox_inches='tight',dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3,3))

axes = fig.add_subplot(111)

axes.set_xlabel('Wavelength $(nm)$', fontsize = 12)
axes.set_ylabel('Intensity (a.u.)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
axes.grid('off')
axes.set_xlim([550,730])
axes.set_ylim([0,7300])
major_ticks_1 = np.arange(0, 7000, 2000)   
axes.set_yticks(major_ticks_1)  

axes.plot(x2,y2, "-", color='black', lw = 1,  label = '0 s',alpha=1  )
axes.plot(x2,z2,"-", color='blue', lw = 1,  label = '2 s',alpha=1 )
axes.plot(x2,a2, "-", color='orange',lw = 1,   label = '4 s' ,alpha=1)
axes.plot(x2,b2, "-", color='green', lw = 1,  label = '8 s' ,alpha=1)


axes.legend(loc = 'upper left', labelspacing = 0.05, fontsize = 10)


plt.savefig("fig3b.jpg", bbox_inches='tight',dpi = 300)

plt.show()

# %%
from skimage.io import imread

x = imread('0s_Oxy_Sulf_mixed-split-green.jpg')
y = imread('0s_Oxy_Sulf_mixed-split-blue.jpg')

fig,(ax1,ax2) = plt.subplots(2,1, figsize=(20,15), sharex = True, sharey = True)
fig.subplots_adjust(hspace=-0.85)
cax = ax1.imshow(x, interpolation='none', cmap=cm.viridis)                   
cbar = fig.colorbar(cax, ticks=[0, 128, 255], orientation='horizontal')
cbar.ax.set_xticklabels(['0', '0.5', '1'], fontsize = 25) 
ax1.axis('off')
ax1.set_adjustable('box-forced')

cax = ax2.imshow(y, interpolation='none', cmap=cm.viridis)                   

ax2.axis('off')
ax2.set_adjustable('box-forced')

plt.savefig("0smap.jpg", dpi = 300)

# %%
from skimage.io import imread

x = imread('6s_Oxy_Sulf_mixed-split-green.jpg')
y = imread('6s_Oxy_Sulf_mixed-split-blue.jpg')

fig,(ax1,ax2) = plt.subplots(2,1, figsize=(20,15), sharex = True, sharey = True)
fig.subplots_adjust(hspace=-0.85)
cax = ax1.imshow(x, interpolation='none', cmap=cm.viridis)                   
cbar = fig.colorbar(cax, ticks=[0, 128, 255], orientation='horizontal')
cbar.ax.set_xticklabels(['0', '0.5', '1'], fontsize = 25) 
ax1.axis('off')
ax1.set_adjustable('box-forced')

cax = ax2.imshow(y, interpolation='none', cmap=cm.viridis)                   

ax2.axis('off')
ax2.set_adjustable('box-forced')

plt.savefig("6smap.jpg", dpi = 300)

# %%
from skimage.io import imread

x = imread('10s_Oxy_Sulf_mixed-split-green.jpg')
y = imread('10s_Oxy_Sulf_mixed-split-blue.jpg')

fig,(ax1,ax2) = plt.subplots(2,1, figsize=(20,15), sharex = True, sharey = True)
fig.subplots_adjust(hspace=-0.85)
cax = ax1.imshow(x, interpolation='none', cmap=cm.viridis)                   
cbar = fig.colorbar(cax, ticks=[0, 128, 255], orientation='horizontal')
cbar.ax.set_xticklabels(['0', '0.5', '1'], fontsize = 55) 
ax1.axis('off')
ax1.set_adjustable('box-forced')

cax = ax2.imshow(y, interpolation='none', cmap=cm.viridis)                   

ax2.axis('off')
ax2.set_adjustable('box-forced')

plt.savefig("10smap.jpg", dpi = 300)

# %%
fig = plt.figure(figsize=(3,3))

axes = fig.add_subplot(111)

axes.set_xlabel('Exposure time (s)', fontsize = 12)
axes.set_ylabel('Intensity (a.u.)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
axes.grid('off')
#axes.set_yticks(axes.get_yticks()[:2])
major_ticks_1 = np.arange(0, 200, 50)   
axes.set_yticks(major_ticks_1)  

axes.plot(x3,y3, alpha=0.7, mfc='green', mew = '1', ls = 'dashed', marker = '8', markersize = 12,label = 'O' )
axes.plot(x3,z3, alpha=0.7, mfc='orange', mew = '1', ls = 'dashed',marker = 'h', markersize = 12, label = 'S' )
axes.set_xlim([-1,11])
axes.set_ylim([25,180])

axes.legend(loc='upper right', fontsize = 12)



plt.savefig("fig3d.jpg",bbox_inches='tight', dpi = 300)

plt.show()

# %%
x_mo6s = [x_mo6s + 0.4 for x_mo6s in x_mo6s]
x_mo10s = [x_mo10s + 0.1 for x_mo10s in x_mo10s]
fig = plt.figure(figsize=(3,3))

fig.canvas.draw()

ax1 = fig.add_subplot(311)
ax1.plot(x_mo0s,y_mo0s, '-o', ms=1, color = 'grey', ls = 'none', lw=2, alpha=0.5, mfc='grey', dash_capstyle = 'butt', mew = '1' )
ax1.fill_between(x_mo0s, z_mo0s, c_mo0s,linestyle = 'solid', lw = 1, label='Mo$^{4 +}$', color= 'dodgerblue', alpha = 0.8)
ax1.fill_between(x_mo0s, a_mo0s, c_mo0s, linestyle = 'solid', lw = 1,  color= 'dodgerblue', alpha = 0.8)
ax1.fill_between(x_mo0s, b_mo0s,c_mo0s,  linestyle = 'solid', lw = 1, label='S 2s', color= 'gold', alpha = 0.8)
ax1.plot(x_mo0s, c_mo0s,  linestyle = 'solid', lw = 2,  color = 'black')




ax2 = fig.add_subplot(312)
ax2.plot(x_mo6s,y_mo6s, '-o', ms=1, color = 'grey', ls = 'none', lw=2, alpha=0.5, mfc='grey', dash_capstyle = 'butt', mew = '1' )
ax2.fill_between(x_mo6s, z_mo6s, e_mo6s, linestyle = 'solid', lw = 1, label='Mo$^{4+}$ ', color= 'dodgerblue', alpha = 0.8)
ax2.fill_between(x_mo6s, a_mo6s, e_mo6s,linestyle = 'solid', lw = 1,  color= 'dodgerblue', alpha = 0.5)
ax2.fill_between(x_mo6s, b_mo6s,e_mo6s, linestyle = 'solid', lw = 1, label='Mo$^{6+}$ ', color= 'limegreen', alpha = 0.8)
ax2.fill_between(x_mo6s, c_mo6s,e_mo6s, linestyle = 'solid', lw = 1,  color= 'limegreen', alpha = 0.8)
ax2.fill_between(x_mo6s, d_mo6s,e_mo6s, linestyle = 'solid', lw = 1, label='S 2s', color= 'gold', alpha = 0.8)
ax2.plot(x_mo6s, e_mo6s, linestyle = 'solid', lw = 3,  color= 'black')


ax2.set_ylabel('Intensity (a.u.)', fontsize = 12)

ax3 = fig.add_subplot(313)
ax3.plot(x_mo10s,y_mo10s, '-o', ms=1, color = 'grey', ls = 'none', lw=2, alpha=0.5, mfc='grey', dash_capstyle = 'butt', mew = '1' )
ax3.fill_between(x_mo10s, z_mo10s, e_mo10s, linestyle = 'solid', lw = 1, label='Mo$^{4+}$ (MoS$_{2}$)', color= 'dodgerblue', alpha = 0.8)
ax3.fill_between(x_mo10s, a_mo10s, e_mo10s,linestyle = 'solid', lw = 1,  color= 'dodgerblue', alpha = 0.5)
ax3.fill_between(x_mo10s, b_mo10s, e_mo10s,linestyle = 'solid', lw = 1, label='Mo$^{6+}$ (MoO$_{3}$)', color= 'limegreen', alpha = 0.8)
ax3.fill_between(x_mo10s, c_mo10s, e_mo10s, linestyle = 'solid', lw = 1,  color= 'limegreen', alpha = 0.8)
ax3.fill_between(x_mo10s, d_mo10s,e_mo10s, linestyle = 'solid', lw = 1, label='S 2s', color= 'gold', alpha = 0.8)
ax3.plot(x_mo10s, e_mo10s, linestyle = 'solid', lw = 2,  color= 'black')




ax3.set_xlabel("Binding energy (eV)", fontsize = 12)

plt.setp(ax1.get_yticklabels(), visible=False, fontsize = 13)
plt.setp(ax2.get_yticklabels(), visible=False, fontsize = 13)
plt.setp(ax3.get_yticklabels(), visible=False, fontsize = 13)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True, fontsize = 14)

plt.setp(ax1.set_xlim([238,222]))

plt.setp(ax2.set_xlim([238,222]))

plt.setp(ax3.set_xlim([238,222]))
#major_ticks_1 = np.arange(238, 223, 1)   
#ax3.set_xticks(major_ticks_1) 
ax3.set_xticks(ax3.get_xticks()[::2])

fig.subplots_adjust(hspace=0.005)

ax2.legend(bbox_to_anchor=(1.1, 2.1),labelspacing=0.01, fontsize = 8)

plt.savefig("fig3e.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
x_s6s = [x_s6s + 0.4 for x_s6s in x_s6s]
x_s10s = [x_s10s + 0.1 for x_s10s in x_s10s]
fig = plt.figure(figsize=(3,3))

fig.canvas.draw()

ax1 = fig.add_subplot(311)
ax1.plot(x_s0s,y_s0s, '-o', ms=1, color = 'grey', ls = 'none', lw=2, alpha=0.5, mfc='grey', dash_capstyle = 'butt', mew = '1' )
ax1.fill(x_s0s, z_s0s, linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= 'g', alpha = 0.5)
ax1.fill(x_s0s, a_s0s,  linestyle = 'solid', lw = 2, label='S 2p$_{1/2}$', color= 'blue', alpha = 0.5)
#ax1.plot(x_s0s, b_s0s, ms = 10, linestyle = 'solid', lw = 3, label='Bgd.', color= 'red')


ax2 = fig.add_subplot(312)
ax2.plot(x_s6s,y_s6s, '-o', ms=1, color = 'grey', ls = 'none', lw=2, alpha=0.5, mfc='grey', dash_capstyle = 'butt', mew = '1' )
ax2.fill(x_s6s, z_s6s,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= 'g', alpha = 0.5)
ax2.fill(x_s6s, a_s6s, linestyle = 'solid', lw = 2, label='S 2p$_{1/2}$', color= 'blue', alpha = 0.5)
#ax2.plot(x_s6s, b_s6s, ms = 10, linestyle = 'solid', lw = 3, label='Bgd.', color= 'red')

ax2.set_ylabel('Intensity (a.u.)', fontsize = 12)

ax3 = fig.add_subplot(313)
ax3.plot(x_s10s,y_s10s, '-o', ms=1, color = 'grey', ls = 'none', lw=2, alpha=0.5, mfc='grey', dash_capstyle = 'butt', mew = '1' )
ax3.fill(x_s10s, z_s10s,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= 'g', alpha = 0.5)
ax3.fill(x_s10s, a_s10s,  linestyle = 'solid', lw = 2, label='S 2p$_{1/2}$', color= 'blue', alpha = 0.5)
#ax3.plot(x_s10s, b_s10s, ms = 10, linestyle = 'solid', lw = 3, label='Bgd.', color= 'red')



ax3.set_xlabel("Binding energy (eV)", fontsize = 12)

plt.setp(ax1.get_yticklabels(), visible=False, fontsize = 13)
plt.setp(ax2.get_yticklabels(), visible=False, fontsize = 13)
plt.setp(ax3.get_yticklabels(), visible=False, fontsize = 13)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True, fontsize = 14)

plt.setp(ax1.set_xlim([164.5,161]))
plt.setp(ax2.set_xlim([164.5,161]))
plt.setp(ax3.set_xlim([164.5,161]))

major_ticks_1 = np.arange(161, 164.5, 1)   
ax3.set_xticks(major_ticks_1) 

fig.subplots_adjust(hspace=0.01)

ax1.legend(loc = 'upper left',labelspacing=0.01, fontsize = 8)

plt.savefig("fig3f.png", dpi=300, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(2,6))

fig.canvas.draw()

ax1 = fig.add_subplot(311)
ax1.plot(x_s0s,y_s0s, '-o', ms=2, color = 'grey', ls = '-', lw=2, alpha=0.5, mfc='grey', dash_capstyle = 'butt', mew = '1' )
#ax2.fill(x_s6s, z_s6s,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= 'g', alpha = 0.5)
#ax2.fill(x_s6s, a_s6s, linestyle = 'solid', lw = 2, label='S 2p$_{1/2}$', color= 'blue', alpha = 0.5)
#ax2.plot(x_s6s, b_s6s, ms = 10, linestyle = 'solid', lw = 3, label='Bgd.', color= 'red')


ax2 = fig.add_subplot(312)
ax2.plot(x_s6s,y_s6s, '-o', ms=2, color = 'grey', ls = '-', lw=2, alpha=0.5, mfc='grey', dash_capstyle = 'butt', mew = '1' )
#ax2.fill(x_s6s, z_s6s,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= 'g', alpha = 0.5)
#ax2.fill(x_s6s, a_s6s, linestyle = 'solid', lw = 2, label='S 2p$_{1/2}$', color= 'blue', alpha = 0.5)
#ax2.plot(x_s6s, b_s6s, ms = 10, linestyle = 'solid', lw = 3, label='Bgd.', color= 'red')

ax2.set_ylabel('Intensity (a.u.)', fontsize = 10)

ax3 = fig.add_subplot(313)
ax3.plot(x_s10s,y_s10s, '-o', ms=2, color = 'grey', ls = '-', lw=2, alpha=0.5, mfc='grey', dash_capstyle = 'butt', mew = '1' )
#ax2.fill(x_s6s, z_s6s,  linestyle = 'solid', lw = 2, label='S 2p$_{3/2}$', color= 'g', alpha = 0.5)
#ax2.fill(x_s6s, a_s6s, linestyle = 'solid', lw = 2, label='S 2p$_{1/2}$', color= 'blue', alpha = 0.5)
#ax2.plot(x_s6s, b_s6s, ms = 10, linestyle = 'solid', lw = 3, label='Bgd.', color= 'red')


ax3.set_xlabel("Binding energy (eV)", fontsize = 10)




plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=True)

plt.setp(ax1.set_xlim([165,164]))
plt.setp(ax1.set_ylim([300,500]))

plt.setp(ax2.set_xlim([165,164]))
plt.setp(ax2.set_ylim([400,800]))

plt.setp(ax3.set_xlim([165,164]))
plt.setp(ax3.set_ylim([400,600]))

xtick = [165, 164.5, 164]
ax3.set_xticks(xtick)

yticks = [400,500,600,700,800]
ax2.set_yticks(yticks)
fig.subplots_adjust(hspace=0.1)

ax2.legend(loc = 'upper left',labelspacing=0.01, fontsize = 8)

plt.savefig("fig3f_S_O.png", dpi=300, bbox_inches='tight')
# Out:
# c:\users\jakub\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
