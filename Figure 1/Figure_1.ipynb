# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
from matplotlib import pyplot
import matplotlib.colors as colors
import bokeh as bk

# %%
x1 = []
y1 = []
z1 = []
a1 = []
b1 = []
c1 = []
d1 = []
e1 = []
f1 = []
g1 = []
h1 = []

with open('IV.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x1.append(float(row[0]))
        y1.append(float(row[1]))
        z1.append(float(row[2]))
        a1.append(float(row[3]))
        b1.append(float(row[4]))
        c1.append(float(row[5]))
        d1.append(float(row[6]))
        e1.append(float(row[7]))
        f1.append(float(row[8]))
        g1.append(float(row[9]))

# %%
x = []
y = []
z = []
a = []
b = []
c = []
d = []
e = []
f = []
g = []
h = []

with open('gate.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))
        z.append(float(row[2]))
        a.append(float(row[3]))
        b.append(float(row[4]))
        c.append(float(row[5]))
        d.append(float(row[6]))
        e.append(float(row[7]))
        f.append(float(row[8]))
        g.append(float(row[9]))

# %%
x2 = []
y2 = []
z2 = []
a2 = []
b2 = []
c2 = []
d2 = []
e2 = []
f2 = []
g2 = []
h2 = []

with open('mobility_as_fnxn_of_gate.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        x2.append(float(row[0]))
        y2.append(float(row[1]))
        z2.append(float(row[2]))
        a2.append(float(row[3]))
        b2.append(float(row[4]))
        c2.append(float(row[5]))
        d2.append(float(row[6]))
        e2.append(float(row[7]))
        f2.append(float(row[8]))
        g2.append(float(row[9]))

# %%
a3 = []
b3 = []

with open('Vth.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        a3.append(float(row[0]))
        b3.append(float(row[1]))

# %%
s1 = []
s2 = []

with open('S_sub.txt','r') as csvfile:
    plots = csv.reader(csvfile, delimiter='\t')
    for row in plots:
        s1.append(float(row[0]))
        s2.append(float(row[1]))

# %%
fig = plt.figure(figsize=(3,3))

axes = fig.add_subplot(111)

axes.set_xlabel('V$_{DS}$ (V)', fontsize = 12)
axes.set_ylabel('I$_{DS}$ ($\mu$A)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
plt.ticklabel_format(style='sci', axis='y')


from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
axes.yaxis.set_major_formatter(formatter)

axes.grid('off')
#axes.set_yticks(axes.get_yticks()[::1])
#axes.set_xticks(axes.get_xticks()[::2])

axes.plot(x1,y1, color='black', linestyle='-', linewidth=3, label = '0 s' )
axes.plot(x1,z1, color='blue', linestyle='-', linewidth=3, label = '2 s')
#axes.plot(x1,a1, color='orange', linestyle='-', linewidth=3, label = '4 s')
axes.plot(x1,b1, color='red', linestyle='-', linewidth=3, label = '6 s')
axes.plot(x1,c1, color='orange', linestyle='-', linewidth=3, label = '8 s')
axes.plot(x1,d1, color='darkviolet', linestyle='-', linewidth=3, label = '10 s')
axes.plot(x1,e1, color='green', linestyle='-', linewidth=3, label = '12 s')
#axes.plot(x1,f1, color='slateblue', linestyle='-', linewidth=3 )
#axes.plot(x1,g1, color='grey', linestyle='-', linewidth=3)
axes.legend(loc='lower right',ncol=2, fontsize = 8)
plt.tight_layout()
plt.savefig("fig1a.jpg", dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3,3))

axes = fig.add_subplot(111)

axes.set_xlabel('V$_{GS}$ (V)', fontsize = 12)
axes.set_ylabel('I$_{DS}$ (A)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
axes.set_ylim([0.00000000001,0.00001])
plt.ticklabel_format(style='sci', axis='y')
axes.set_yscale('log')

axes.grid('off')


axes.plot(x,y, color='black', linestyle='-', linewidth=3, label = '0 s' )
#axes.plot(x,z, color='blue', linestyle='-', linewidth=3, label = '2 s')
#axes.plot(x,a, color='orange', linestyle='-', linewidth=5, label = '4 s')
axes.plot(x,b, color='red', linestyle='-', linewidth=3, label = '6 s')
axes.plot(x,c, color='orange', linestyle='-', linewidth=3, label = '8 s')
axes.plot(x,d, color='darkviolet', linestyle='-', linewidth=3, label = '10 s')
axes.plot(x,e, color='green', linestyle='-', linewidth=3, label = '12 s')
#axes.plot(x,f, color='slateblue', linestyle='-', linewidth=5,label = '14 s' )
#axes.plot(x,g, color='grey', linestyle='-', linewidth=5, label = '16 s')
axes.set_yticks(axes.get_yticks()[::2])
axes.set_xticks(axes.get_xticks()[::3])

#axes.legend(bbox_to_anchor=(2, 2))

#plt.tight_layout()
plt.savefig("fig1b.jpg",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(3,3))

axes = fig.add_subplot(111)

axes.set_xlabel('V$_{GS}$ (V)', fontsize = 12)
axes.set_ylabel('$\mu_{FE}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(fontsize = 12)
axes.grid('off')

axes.set_ylim([0, 131])
axes.set_xlim([-40, 60])
axes.plot(x2,y2, color='black', linestyle='-', linewidth=3, label = '0 s' )
axes.plot(x2,z2, color='blue', linestyle='-', linewidth=3, label = '2 s')
#axes.plot(x2,a2, color='olive', linestyle='-', linewidth=3, label = '4 s')
axes.plot(x2,b2, color='red', linestyle='-', linewidth=3, label = '6 s')
axes.plot(x2,c2, color='orange', linestyle='-', linewidth=3, label = '8 s')
axes.plot(x2,d2, color='darkviolet', linestyle='-', linewidth=3, label = '10 s')
axes.plot(x2,e2, color='green', linestyle='-', linewidth=3, label = '12 s')
#axes.plot(x2,f2, color='slateblue', linestyle='-', linewidth=3,label = '14 s' )
#axes.plot(x2,g2, color='coral', linestyle='-', linewidth=3, label = '16 s')
axes.set_yticks(axes.get_yticks()[::3])
axes.axvspan(-40, 5, color='green', alpha=0.5)
#axes.set_xticks(axes.get_xticks()[::3])
#axes.legend(loc='upper left', fontsize = 19)
#plt.tight_layout()
plt.savefig("fig1c.png", bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(6,3.5))

fig.canvas.draw()

ax1 = fig.add_subplot(211)
ax1.plot(a3,b3, '-o', ms=10, color = 'r', ls = 'none', lw=2, alpha=0.7, mfc='red', dash_capstyle = 'butt', mew = '2', 
              label = '$V_{TH}$' ) 


ax2 = fig.add_subplot(212)
ax2.plot(s1,s2, '-o', ms=10, color = 'b', ls = 'none', lw=2, alpha=0.7, mfc='blue', mew = '2', label = '$S_{sub}$' )

ax2.set_xlabel('Exposure time (s)', fontsize = 12)
ax2.set_ylabel('(V dec$^{-1}$)', fontsize = 12)
ax1.set_ylabel('(V)', fontsize = 12)
ax1.set_xlabel('None')
plt.grid('off')

plt.setp(ax1.get_yticklabels(), visible=True, fontsize = 12)
plt.setp(ax2.get_yticklabels(), visible=True, fontsize = 12)
plt.setp(ax1.get_xticklabels(), visible=True, fontsize = 12)
plt.setp(ax2.get_xticklabels(), visible=True, fontsize = 12)



plt.setp(ax1.set_xlim([-0.5,17]))
plt.setp(ax2.set_xlim([-0.5,17]))
plt.setp(ax1.set_ylim([-60,75]))
plt.setp(ax2.set_ylim([0,40]))
ax1.axvspan(5, 7, color='green', alpha=0.5)
ax2.axvspan(5, 7, color='green', alpha=0.5)

fig.subplots_adjust(hspace=0.01)

ax1.legend(loc='lower right',ncol = 4, fontsize = 15)
ax2.legend(loc='lower right',ncol = 4, fontsize = 15)


#major_ticks_1 = np.arange(-61, 76, 20)   
#ax1.set_yticks(major_ticks_1)   
major_ticks_1 = np.arange(0, 18, 2)   
ax1.set_xticks(major_ticks_1) 
major_ticks_2 = np.arange(0, 18, 2)   
ax2.set_xticks(major_ticks_2)   
ax1.set_yticks(ax1.get_yticks()[::3])
#ax1.set_xticks(ax1.get_xticks()[::1])
ax2.set_yticks(ax2.get_yticks()[::3])
#ax2.set_xticks(ax2.get_xticks()[::1])

plt.savefig("figs1d_e.png",bbox_inches='tight', dpi = 300)


plt.show()

# %%
fig = plt.figure(figsize=(5,10))
min, max = (-60, 60)
step = 10
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['blue','red'])
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)

CS3 = plt.contourf(Z, levels, cmap='viridis', fontsize = 40)

plt.clf()  
  
plt.colorbar(CS3) # using the colorbar info I got from contourf 


opened_file = open("mobility_over_time.txt")
csv_data = csv.reader(opened_file, delimiter="\t")
parsed_data = []

for row in csv_data:
    parsed_data.append(row)
opened_file.close()

data = np.array(parsed_data)
new_data = data[::3]
ax=plt.gca()
colormap = plt.get_cmap('viridis')
ax.set_color_cycle([colormap(k) for k in np.linspace(0, 1, 122)])
#ax.axvspan(5.5, 6.5, color='orange', alpha=0.5)
for i in range(1,122):
        plt.plot(new_data[0:8,0],new_data[0:8,i], lw = 2)
        axes = plt.gca()
axes.set_xlim([0,10])
axes.set_ylim([0,125])
axes.set_xlabel('Exposure time (s)', fontsize = 25)
axes.set_ylabel('$\mu_{FE}$ (cm$^2$ V$^{-1}$ s$^{-1}$)', fontsize = 25)
plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.tight_layout()
plt.savefig("fig1f.png", dpi=300)
# Out:
# C:\Users\Jakub\Anaconda3\lib\site-packages\matplotlib\cbook.py:137: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
